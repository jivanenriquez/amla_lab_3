# %% [markdown]
# # **Lab: Model Serving**

# %% [markdown]
# ## Exercise 1: EDA and Baseline Model
#
# In this exercise we will start our data science project by preparing the dataset for modeling.
#
# The steps are:
# 1.   Setup Environment
# 2.   Load and explore dataset
# 3.   Split Dataset
# 4.   Get Baseline model
# 5.   Push changes

# %% [markdown]
# ## 0. Pre-Requisites
#
# - Created a folder structure following Cookiecutter Data Science template
# - Initialise a Git repository linked to Github and created a dedicated branch
# - Install required Python dependencies with uv
# - Launched Jupyter Lab using uv

# %% [markdown]
# ### 1. Setup Environment

# %% [markdown]
# **[1.1]** Download the dataset into the sub-folder data/raw (https://github.com/aso-uts/labs_datasets/raw/main/36120-adv_mla/lab03/archive.zip)

# %%
# For Windows users, you can download and install WGET. Or you can manually download the file from the link and save it to specified path
! wget -P ~/Projects/adv_mla_2026/adv_mla_lab_3/data/raw https://github.com/aso-uts/labs_datasets/raw/main/36120-adv_mla/lab03/archive.zip

# %% [markdown]
# **[1.2]** Navigate the folder `notebooks` and create a new jupyter notebook called `1_baseline.ipynb`

# %% [markdown]
# ### 2.   Load and Explore Dataset

# %% [markdown]
# **[2.1]** Launch magic commands to automatically reload modules

# %%
# Placeholder for student's code (Python code)

# %% [markdown]
# **[2.2]** Import the pandas and numpy packages

# %%
# Placeholder for student's code (Python code)

# %% [markdown]
# **[2.3]** Load the dataset into a dataframe called `df`

# %%
# Placeholder for student's code (Python code)

# %% [markdown]
# **[2.4]** Display the first 5 rows of `df`

# %%
# Placeholder for student's code (Python code)

# %% [markdown]
# **[2.5]** Display the dimensions of `df`

# %%
# Placeholder for student's code (Python code)

# %% [markdown]
# **[2.6]** Display the summary (info) of `df`

# %%
# Placeholder for student's code (Python code)

# %% [markdown]
# **[2.7]** Display the descriptive statistics of `df`

# %%
# Placeholder for student's code (Python code)

# %% [markdown]
# ### 3. Split Dataset

# %% [markdown]
# **[3.1]** Create a copy of `df` and save it into a variable called `df_cleaned`

# %%
# Placeholder for student's code (Python code)

# %% [markdown]
# **[3.2]** Convert the values of `Heart_Disease` into numerical type and save the results in a variable called `target`

# %%
# Placeholder for student's code (Python code)

# %% [markdown]
# **[3.3]** Import the function `split_sets_random` from your custom package and split the data into several sets as Numpy arrays

# %%
# Placeholder for student's code (Python code)

# %% [markdown]
# **[3.4]** Import the function `save_sets` from your custom package and save the sets into the folder `data/processed`

# %%
# Placeholder for student's code (Python code)

# %% [markdown]
# ### 4. Baseline Model

# %% [markdown]
# **[4.1]** Import the DummyClassifier module from sklearn

# %%
# Placeholder for student's code (Python code)

# %% [markdown]
# **[4.2]** Instantiate a `DummyClassifier` and save it into a variable called `base_model`

# %%
# Placeholder for student's code (Python code)

# %% [markdown]
# **[4.3]** Make a prediction using `fit_predict()` and save the results in a variable called `y_base`

# %%
# Placeholder for student's code (Python code)

# %% [markdown]
# **[4.4]** Import the function `print_classifier_scores` from your custom package and display the Accuracy and F1 scores of this baseline model on the training set

# %%
# Placeholder for student's code (Python code)

# %% [markdown]
# ### 5.   Push changes

# %% [markdown]
# **[5.1]** Add you changes to git staging area

# %%
# Placeholder for student's code (command line)

# %% [markdown]
# **[5.2]** Create the snapshot of your repository and add a description

# %%
# Placeholder for student's code (command line)

# %% [markdown]
# **[5.3]** Push your snapshot to Github

# %%
# Placeholder for student's code (command line)

# %% [markdown]
# **[5.4]** Go to Github and merge the branch after reviewing the code and fixing any conflict

# %% [markdown]
# **[5.5]** Check out to the master branch

# %%
# Placeholder for student's code (command line)

# %% [markdown]
# **[5.6]** Pull the latest updates

# %%
# Placeholder for student's code (command line)
